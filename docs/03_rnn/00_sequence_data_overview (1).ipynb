# %% [markdown]
# A sequence is data with an inherent order.

# %%
sequence = [1, 3, 5, 7, 9, 11]

print("Sequence:", sequence)
print(":Length:", len(sequence))

for i, value in enumerate(sequence):
    print(f"t={i}: {value}")
# Out:
# A sequence: [1, 3, 5, 7, 9, 11]
# length: 6
# t=0: 1
# t=1: 3
# t=2: 5
# t=3: 7
# t=4: 9
# t=5: 11
